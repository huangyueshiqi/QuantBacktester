# %%
import pickle

import cx_Oracle
# %load_ext cudf.pandas
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager

# %%
import statistics

data=[13.1175,11.413,1.375631,1.69024,2.409,1.593,-0.002,1.26,-0.04, 0.549,0.057]
statistics.stdev(data)
# Out:
# 4.644986407115574

# %%
import numpy as np
np.mean(data)
# Out:
# 3.038397363636364

# %%
3.03/4.64
# Out:
# 0.6530172413793104

# %%
t1=[0.051476801244456416, -0.015273514339140148, 0.0014607917306330709, 0.007751465788982337, 0.04859807890269541, 0.027485425569497623, -0.02543252982699329, 0.045709278597202085, 0.029346202264664445, -0.015871835004435786, -0.05720749189966212, -0.2711689476122978, 0.07579395269652045, -0.016383246267816176, -0.06090558428784654, -0.16138698608671942, 0.030043509296959092, 0.08984226554461816, 0.13171002283106048, 0.11794563836446081, -0.01355790194648554, -0.10338319573093346, -0.06799621627020747]

# %%
len(t1)
# Out:
# 23

# %%
np.sqrt(252)
# Out:
# 15.874507866387544

# %%
157892592.23062986-136603170.23062986
# Out:
# 21289422.0

# %%
2024-09-18, 日期:2024-09-18,现金:140180758.90869915,资产市值:195511254.69869915,持仓市值:75211412.3

# %%
140180758.90869915+75211412.3-21289422.0
# Out:
# 194102749.20869917

# %%
2015-09-15, 日期:2015-09-15,现金:71673611.83816308,资产市值:156784007.83816308,持仓市值:85110396.0

# %%
71673611.83816308+85110396.0
# Out:
# 156784007.83816308
